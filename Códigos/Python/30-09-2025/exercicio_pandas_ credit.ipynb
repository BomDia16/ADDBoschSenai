# %%
#importar biblioteca
import pandas as pd
#variável arquivo csv

arquivo = 'Credit.csv'

var = pd.read_csv(arquivo)

print(var)
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
# 5 primeiras head()

print(var.head())
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
#5 ultimos tail()

print(var.tail())
# Out:
#     checking_status  duration                    credit_history  \
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount savings_status  employment  \
# 995  furniture/equipment           1736           <100      4<=X<7
# 996           'used car'           3857           <100      1<=X<4
# 997             radio/tv            804           <100         >=7
# 998             radio/tv           1845           <100      1<=X<4
# 999           'used car'           4576     100<=X<500  unemployed
#
#      installment_commitment       personal_status other_parties  ...  \
# 995                       3  'female div/dep/mar'          none  ...
# ...

# %%
#resumo - quantidade de linhas e colunas shape

print(var.shape)
# Out:
# (1000, 21)

# %%
#lista completa

print(var.to_string())
# Out:
#     checking_status  duration                    credit_history               purpose  credit_amount      savings_status  employment  installment_commitment       personal_status   other_parties  residence_since   property_magnitude  age other_payment_plans     housing  existing_credits                          job  num_dependents own_telephone foreign_worker class
# 0                <0         6  'critical/other existing credit'              radio/tv           1169  'no known savings'         >=7                       4         'male single'            none                4        'real estate'   67                none         own                 2                      skilled               1           yes            yes  good
# ...

# %%
#trazendo informações info()

print(var.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   int64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   int64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   int64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   int64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   int64
#  13  other_payment_plans     1000 non-null   object
# ...

# %%
#dropna()

print(var.dropna())
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
#shape

print(var.shape)
# Out:
# (1000, 21)

# %%
#describe - resumo estatístico

print(var.describe())
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
#mostrar um elemento específico -> loc[]

print(var.loc[10])
# Out:
# checking_status                       0<=X<200
# duration                                    12
# credit_history                 'existing paid'
# purpose                              'new car'
# credit_amount                             1295
# savings_status                            <100
# employment                                  <1
# installment_commitment                       3
# personal_status           'female div/dep/mar'
# other_parties                             none
# residence_since                              1
# property_magnitude                         car
# age                                         25
# other_payment_plans                       none
# housing                                   rent
# existing_credits                             1
# job                                    skilled
# num_dependents                               1
# own_telephone                             none
# foreign_worker                             yes
# ...

# %%
#mostrar intervalo  loc[]

print(var.loc[1:20])
# Out:
#    checking_status  duration                    credit_history  \
# 1         0<=X<200        48                   'existing paid'
# 2    'no checking'        12  'critical/other existing credit'
# 3               <0        42                   'existing paid'
# 4               <0        24              'delayed previously'
# 5    'no checking'        36                   'existing paid'
# 6    'no checking'        24                   'existing paid'
# 7         0<=X<200        36                   'existing paid'
# 8    'no checking'        12                   'existing paid'
# 9         0<=X<200        30  'critical/other existing credit'
# 10        0<=X<200        12                   'existing paid'
# 11              <0        48                   'existing paid'
# 12        0<=X<200        12                   'existing paid'
# 13              <0        24  'critical/other existing credit'
# 14              <0        15                   'existing paid'
# ...

# %%
# mostrar linha separadas loc[[]]

print(var.loc[[1, 3]])
# Out:
#   checking_status  duration   credit_history              purpose  \
# 1        0<=X<200        48  'existing paid'             radio/tv
# 3              <0        42  'existing paid'  furniture/equipment
#
#    credit_amount savings_status employment  installment_commitment  \
# 1           5951           <100     1<=X<4                       2
# 3           7882           <100     4<=X<7                       2
#
#         personal_status other_parties  ...  property_magnitude age  \
# 1  'female div/dep/mar'          none  ...       'real estate'  22
# 3         'male single'     guarantor  ...    'life insurance'  45
#
#    other_payment_plans     housing existing_credits      job num_dependents  \
# 1                 none         own                1  skilled              1
# 3                 none  'for free'                1  skilled              2
#
#    own_telephone foreign_worker class
# 1           none            yes   bad
# 3           none            yes  good
#
# ...

# %%
#filtrar dados objeto.loc [objeto[]] 

print(var.loc[var['age'] == 30])
# Out:
#     checking_status  duration                    credit_history  \
# 32         0<=X<200        18                   'existing paid'
# 40    'no checking'        30                   'existing paid'
# 51         0<=X<200        27              'delayed previously'
# 70    'no checking'        36                   'existing paid'
# 88               <0        18                   'existing paid'
# 108              <0        24                   'existing paid'
# 116              <0        42                   'existing paid'
# 125              <0        12  'critical/other existing credit'
# 127        0<=X<200        12                   'existing paid'
# 141        0<=X<200        36                   'existing paid'
# 145        0<=X<200        48                        'all paid'
# 161   'no checking'        18  'critical/other existing credit'
# 181        0<=X<200        36              'delayed previously'
# 222   'no checking'        12                   'existing paid'
# ...
