# %% [markdown]
# Tuplas são estruturas semelhantes às listas, mas imutáveis, ou seja, depois de criadas, seus elementos
# não podem ser alterados, adicionados ou removidos.

# %%
#Tuplas podem ser criadas com ou sem parênteses:
cores = ("vermelho", "verde", "azul")
numeros = 1, 2, 3, 4

# %%
#A indexação  funciona igual às listas:
print(cores[1])
# Out:
# verde
